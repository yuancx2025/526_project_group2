# %% [markdown]
# <a href="https://colab.research.google.com/github/yuancx2025/526_project_group2/blob/main/competetive_structual_analysis%20/%20Causal_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Input the ticket level data

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/yuancx2025/526_project_group2/main/KG_cost_small.csv"
data = pd.read_csv(url)

data.info()      # check structure
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222252 entries, 0 to 222251
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   origin        222252 non-null  object
#  1   dest          222252 non-null  object
#  2   year          222252 non-null  int64
#  3   HHI_route     222252 non-null  float64
#  4   gini_airline  222252 non-null  float64
#  5   meanfare      222252 non-null  float64
#  6   maxfare       222252 non-null  float64
#  7   minfare       222252 non-null  float64
#  8   gini          222252 non-null  float64
#  9   pop_o         222252 non-null  float64
#  10  pop_d         222252 non-null  float64
#  11  airline_id    222252 non-null  int64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 20.3+ MB
#   origin dest  year  HHI_route  gini_airline    meanfare  maxfare  minfare  \
# 0    ANC  FAI  2002   0.998700      0.033060  133.250000    144.5    122.0
# 1    ANC  FAI  2002   0.994030      0.017388  136.812500    165.5    122.0
# 2    ANC  FAI  2003   0.998211      0.062617  133.750000    150.5    117.0
# 3    ANC  FAI  2002   0.994769      0.033655  130.916672    151.5    120.0
# 4    ANC  FAI  2005   0.997391      0.021482  155.166672    163.0    148.0
#
#        gini     pop_o    pop_d  airline_id
# 0  0.042214  275043.0  31324.0       20320
# 1  0.034776  275043.0  31324.0       20320
# 2  0.062617  275043.0  31324.0       20320
# 3  0.053363  275043.0  31324.0       20320
# 4  0.021482  275043.0  31324.0       20320

# %% [markdown]
# Input graph level data (help visualize)

# %%
import pandas as pd

airports_raw = pd.read_csv("https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat", header=None)

airports = airports_raw[[1, 2, 3, 4, 5, 6, 7, 8, 9]]
airports.columns = ["airport_name", "city", "country", "IATA", "ICAO", "lat", "lon", "alt", "timezone"]


airports = airports[airports["IATA"].notna()]
airports.head()
# Out:
#                                   airport_name          city  \
# 0                               Goroka Airport        Goroka
# 1                               Madang Airport        Madang
# 2                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3                               Nadzab Airport        Nadzab
# 4  Port Moresby Jacksons International Airport  Port Moresby
#
#             country IATA  ICAO       lat         lon   alt timezone
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998  5282       10
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001    20       10
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005  5388       10
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977   239       10
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001   146       10

# %% [markdown]
# Combine tow data.

# %%
data = data.merge(
    airports[["IATA", "lat", "lon", "country", "city"]],
    how="left",
    left_on="origin",
    right_on="IATA"
).rename(columns={
    "lat": "origin_lat",
    "lon": "origin_lon",
    "country": "origin_country",
    "city": "origin_city"
})


# Merge destination coordinates
data = data.merge(
    airports[["IATA", "lat", "lon", "country", "city"]],
    how="left",
    left_on="dest",
    right_on="IATA"
).rename(columns={
    "lat": "dest_lat",
    "lon": "dest_lon",
    "country": "dest_country",
    "city": "dest_city"
})

# %% [markdown]
# Check merge level and shrink into US ariline market

# %%
data[["origin", "origin_lat", "origin_lon", "dest", "dest_lat", "dest_lon"]].head()
data["origin_lat"].notna().mean(), data["dest_lat"].notna().mean()
data_us = data[(data["origin_country"]=="United States") &
               (data["dest_country"]=="United States")]

# %%
routes_2005 = (data_us[data_us["year"]==2005]
               .groupby(["origin","dest"], as_index=False)
               .agg({"origin_lat":"first","origin_lon":"first",
                     "dest_lat":"first","dest_lon":"first",
                     "HHI_route":"mean","pop_o":"first","pop_d":"first"}))
routes_2005["market_type"] = pd.cut(
    routes_2005["HHI_route"],
    bins=[-float("inf"), 0.2, 0.6, float("inf")],
    labels=["competitive", "oligopoly", "monopoly"]
)

#routes_2005.info()
#info of the only competitive market in dataset
routes_2005[routes_2005["market_type"]=="competitive"]
# Out:
#      origin dest  origin_lat  origin_lon   dest_lat    dest_lon  HHI_route  \
# 1102    HNL  LAX   21.320620 -157.924228  33.942501 -118.407997   0.196450
# 1536    LAX  HNL   33.942501 -118.407997  21.320620 -157.924228   0.199042
#
#            pop_o       pop_d  market_type
# 1102    909863.0  12923547.0  competitive
# 1536  12923547.0    909863.0  competitive

# %%
order_list = ["competitive", "oligopoly", "monopoly"]
route_counts_ordered = routes_2005["market_type"].value_counts().reindex(order_list)
route_counts_ordered
# Out:
# market_type
# competitive       2
# oligopoly       617
# monopoly       2449
# Name: count, dtype: int64

# %% [markdown]
# Graph the

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(3, 4))
sns.countplot(data=routes_2005,
              x="market_type",
              order=["competitive","oligopoly","monopoly"],
              palette={"competitive":"#1b9e77",
                       "oligopoly":"#d95f02",
                       "monopoly":"#7570b3"})
plt.title("Number of Routes by Market Type (2005)")
plt.xlabel("Market Type")
plt.ylabel("Number of Routes")
plt.show()
# Out:
# /tmp/ipython-input-590396753.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=routes_2005,

# %%
# !pip install geodatasets --quiet

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets
import matplotlib.pyplot as plt
from google.colab import files
# --- US basemap ---
world = gpd.read_file(geodatasets.get_path("naturalearth.land"))
usa = world.cx[-130:-65, 24:50]

# --- choose a small sample to reduce clutter ---
routes_sample = routes_2005.sample(frac=0.15, random_state=42)

# --- (re‑)build geometry safely ---
from shapely.geometry import LineString
routes_sample = routes_sample.dropna(subset=["origin_lon","origin_lat","dest_lon","dest_lat"])
routes_sample["geometry"] = [
    LineString([(r.origin_lon, r.origin_lat), (r.dest_lon, r.dest_lat)])
    for _, r in routes_sample.iterrows()
]
routes_gdf = gpd.GeoDataFrame(routes_sample, geometry="geometry", crs="EPSG:4326")

color_map = {
    "competitive": "#1b9e77",
    "oligopoly": "#d95f02",
    "monopoly": "#7570b3"
}

fig, ax = plt.subplots(figsize=(5, 3))
usa.plot(ax=ax, color="lightgray", edgecolor="white")

# --- plot each market type if it exists ---
for label, color in color_map.items():
    subset = routes_gdf[routes_gdf["market_type"] == label]
    if len(subset) > 0 and subset.geometry.notna().any():
        subset = subset[subset.geometry.is_valid]
        subset.plot(ax=ax, color=color, linewidth=0.4,
                    alpha=0.4, label=label)

# --- decorations ---
plt.legend(title="Market Type", loc="lower left", frameon=True)
plt.title("U.S. Airline Routes by Market Type (2005)", fontsize=14, weight="bold")
plt.xlim(-130, -65)
plt.ylim(24, 50)
plt.axis("off")
plt.tight_layout()
plt.show()
plt.figure()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-615085128.py in <cell line: 0>()
#       1 import geopandas as gpd
#       2 import matplotlib.pyplot as plt
# ----> 3 import geodatasets
#       4 import matplotlib.pyplot as plt
#       5 from google.colab import files
#
# ModuleNotFoundError: No module named 'geodatasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd


data["route"] = data["origin"].astype(str) + "_" + data["dest"].astype(str)
df = data.copy()
# check variable
df[['route','year','HHI_route','meanfare','maxfare','minfare','gini','gini_airline','airline_id']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222252 entries, 0 to 222251
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   route         222252 non-null  object
#  1   year          222252 non-null  int64
#  2   HHI_route     222252 non-null  float64
#  3   meanfare      222252 non-null  float64
#  4   maxfare       222252 non-null  float64
#  5   minfare       222252 non-null  float64
#  6   gini          222252 non-null  float64
#  7   gini_airline  222252 non-null  float64
#  8   airline_id    222252 non-null  int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 15.3+ MB

# %%
# !pip install linearmodels --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 4.8 MB/s eta 0:00:00

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm


df = df.set_index(['route','year'])
# regression 1 ： mean fare
mod_mean = PanelOLS.from_formula(
    'meanfare ~ HHI_route + EntityEffects + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

# regression 2 ： min fare
mod_min = PanelOLS.from_formula(
    'minfare ~ HHI_route + EntityEffects + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

# regression 3 ： max fare
mod_max = PanelOLS.from_formula(
    'maxfare ~ HHI_route + EntityEffects + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

# regression 4 ： gini
mod_gini = PanelOLS.from_formula(
    'gini ~ HHI_route + EntityEffects + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

print(mod_mean.summary)
print(mod_min.summary)
print(mod_gini.summary)
print(mod_max.summary)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:               meanfare   R-squared:                        0.0430
# Estimator:                   PanelOLS   R-squared (Between):              0.4686
# No. Observations:              222252   R-squared (Within):               0.0432
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.4014
# Time:                        19:52:10   Log-likelihood                -1.107e+06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      9755.8
# Entities:                        5113   P-value                           0.0000
# Avg Obs:                       43.468   Distribution:                F(1,217125)
# Min Obs:                       1.0000
# Max Obs:                       382.00   F-statistic (robust):             721.64
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,217125)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route      61.067     2.2732     26.863     0.0000      56.611      65.522
# ==============================================================================
#
# F-test for Poolability: 143.31
# P-value: 0.0000
# Distribution: F(5125,217125)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                minfare   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.1190
# No. Observations:              222252   R-squared (Within):               0.0002
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.0987
# Time:                        19:52:12   Log-likelihood                -1.017e+06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      91.365
# Entities:                        5113   P-value                           0.0000
# Avg Obs:                       43.468   Distribution:                F(1,217125)
# Min Obs:                       1.0000
# Max Obs:                       382.00   F-statistic (robust):             22.395
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,217125)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route      3.9518     0.8351     4.7323     0.0000      2.3151      5.5885
# ==============================================================================
#
# F-test for Poolability: 16.746
# P-value: 0.0000
# Distribution: F(5125,217125)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   gini   R-squared:                        0.0054
# Estimator:                   PanelOLS   R-squared (Between):              0.2163
# No. Observations:              222252   R-squared (Within):               0.0077
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.1746
# Time:                        19:52:16   Log-likelihood                 3.394e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1188.7
# Entities:                        5113   P-value                           0.0000
# Avg Obs:                       43.468   Distribution:                F(1,217125)
# Min Obs:                       1.0000
# Max Obs:                       382.00   F-statistic (robust):             112.12
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,217125)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route      0.0318     0.0030     10.588     0.0000      0.0259      0.0377
# ==============================================================================
#
# F-test for Poolability: 65.691
# P-value: 0.0000
# Distribution: F(5125,217125)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                maxfare   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.2129
# No. Observations:              222252   R-squared (Within):               0.0008
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.0997
# Time:                        19:52:14   Log-likelihood                -1.732e+06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      89.752
# Entities:                        5113   P-value                           0.0000
# Avg Obs:                       43.468   Distribution:                F(1,217125)
# Min Obs:                       1.0000
# Max Obs:                       382.00   F-statistic (robust):             46.133
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,217125)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route      97.423     14.344     6.7921     0.0000      69.310      125.54
# ==============================================================================
#
# F-test for Poolability: 10.816
# P-value: 0.0000
# Distribution: F(5125,217125)
#
# Included effects: Entity, Time

# %%
import pandas as pd

data["airline_route_grp"] = data["airline_id"].astype(str) + "_" + data["route"].astype(str)
df = data.copy()
# check variable
df[['route','year','HHI_route','meanfare','maxfare','minfare','gini','gini_airline','airline_id','airline_route_grp']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222252 entries, 0 to 222251
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   route              222252 non-null  object
#  1   year               222252 non-null  int64
#  2   HHI_route          222252 non-null  float64
#  3   meanfare           222252 non-null  float64
#  4   maxfare            222252 non-null  float64
#  5   minfare            222252 non-null  float64
#  6   gini               222252 non-null  float64
#  7   gini_airline       222252 non-null  float64
#  8   airline_id         222252 non-null  int64
#  9   airline_route_grp  222252 non-null  object
# dtypes: float64(6), int64(2), object(2)
# memory usage: 17.0+ MB

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm

df = df.set_index(['airline_route_grp','year'])
# regression 1 ： mean fare
mod_mean1 = PanelOLS.from_formula(
    'meanfare ~ HHI_route + EntityEffects  + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

# regression 2 ： min fare
mod_min1 = PanelOLS.from_formula(
    'minfare ~ HHI_route + EntityEffects + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

# regression 3 ： max fare
mod_max1 = PanelOLS.from_formula(
    'maxfare ~ HHI_route + EntityEffects + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

# regression 4 ： gini
mod_gini1 = PanelOLS.from_formula(
    'gini ~ HHI_route + EntityEffects + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

print(mod_mean1.summary)
print(mod_min1.summary)
print(mod_gini1.summary)
print(mod_max1.summary)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:               meanfare   R-squared:                        0.0221
# Estimator:                   PanelOLS   R-squared (Between):              0.3086
# No. Observations:              222252   R-squared (Within):               0.0230
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.2933
# Time:                        19:53:35   Log-likelihood                -1.073e+06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4756.1
# Entities:                       11544   P-value                           0.0000
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):             542.75
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route      42.344     1.8176     23.297     0.0000      38.781      45.906
# ==============================================================================
#
# F-test for Poolability: 89.916
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                minfare   R-squared:                        0.0031
# Estimator:                   PanelOLS   R-squared (Between):              0.1619
# No. Observations:              222252   R-squared (Within):               0.0029
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.2287
# Time:                        19:53:37   Log-likelihood                 -9.68e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      650.66
# Entities:                       11544   P-value                           0.0000
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):             142.69
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route      9.7512     0.8163     11.945     0.0000      8.1513      11.351
# ==============================================================================
#
# F-test for Poolability: 21.483
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   gini   R-squared:                        0.0008
# Estimator:                   PanelOLS   R-squared (Between):              0.0766
# No. Observations:              222252   R-squared (Within):               0.0017
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.0680
# Time:                        19:53:41   Log-likelihood                 3.785e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      177.83
# Entities:                       11544   P-value                           0.0000
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):             22.033
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route      0.0119     0.0025     4.6940     0.0000      0.0069      0.0169
# ==============================================================================
#
# F-test for Poolability: 47.836
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                maxfare   R-squared:                     1.983e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0466
# No. Observations:              222252   R-squared (Within):           -6.529e-05
# Date:                Mon, Nov 17 2025   R-squared (Overall):             -0.0260
# Time:                        19:53:39   Log-likelihood                -1.721e+06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.1775
# Entities:                       11544   P-value                           0.0410
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):             2.2254
#                                         P-value                           0.1358
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# HHI_route     -23.092     15.479    -1.4918     0.1358     -53.431      7.2472
# ==============================================================================
#
# F-test for Poolability: 7.0768
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time

# %%
import numpy as np


routes_2005['origin_size'] = pd.qcut(routes_2005['pop_o'], q=5, labels=['S','M','L','XL','XXL'])
routes_2005['dest_size']   = pd.qcut(routes_2005['pop_d'], q=5, labels=['S','M','L','XL','XXL'])

threshold = routes_2005['pop_o'].quantile(0.8)
routes_2005['origin_bigcity'] = np.where(routes_2005['pop_o'] >= threshold, 1, 0)
routes_2005['dest_bigcity']   = np.where(routes_2005['pop_d'] >= threshold, 1, 0)

routes_2005['route_city_type'] = routes_2005['origin_bigcity'] +  routes_2005['dest_bigcity']
routes_2005.info()

# %%
data['origin_size'] = pd.qcut(data['pop_o'], q=5, labels=['S','M','L','XL','XXL'])
data['dest_size']   = pd.qcut(data['pop_d'], q=5, labels=['S','M','L','XL','XXL'])

threshold = data['pop_o'].quantile(0.8)
data['origin_bigcity'] = np.where(data['pop_o'] >= threshold, 1, 0)
data['dest_bigcity']   = np.where(data['pop_d'] >= threshold, 1, 0)

data['route_city_type'] = data['origin_bigcity'] +  data['dest_bigcity']
data.info()

# %%
data['route_city_type'].head()

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm
import pandas as pd

df = data.copy()


df = df.set_index(['route', 'year'])


HHI_city = PanelOLS.from_formula(
    'HHI_route ~ route_city_type + TimeEffects',
    data=df
).fit(cov_type='clustered', cluster_entity=True)

print(HHI_city.summary)

# %%
data["market_type"] = pd.cut(
    data["HHI_route"],
    bins=[-float("inf"), 0.8, float("inf")],
    labels=["competitive market", "hob-space"]
)

# %%
df = data.copy()
# check variable
df[['route','year','HHI_route','meanfare','maxfare','minfare','gini','gini_airline','airline_id','airline_route_grp','market_type']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222252 entries, 0 to 222251
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   route              222252 non-null  object
#  1   year               222252 non-null  int64
#  2   HHI_route          222252 non-null  float64
#  3   meanfare           222252 non-null  float64
#  4   maxfare            222252 non-null  float64
#  5   minfare            222252 non-null  float64
#  6   gini               222252 non-null  float64
#  7   gini_airline       222252 non-null  float64
#  8   airline_id         222252 non-null  int64
#  9   airline_route_grp  222252 non-null  object
#  10  market_type        222252 non-null  category
# dtypes: category(1), float64(6), int64(2), object(2)
# memory usage: 17.2+ MB

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm

df = df.set_index(['airline_route_grp','year'])
# regression 1 ： mean fare
mod_mean2 = PanelOLS.from_formula(
    'meanfare ~ market_type + EntityEffects  + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)

mod_min2 = PanelOLS.from_formula(
    'minfare ~ market_type + EntityEffects  + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)
mod_gini2 = PanelOLS.from_formula(
    'gini ~ market_type + EntityEffects  + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)
mod_max2 = PanelOLS.from_formula(
    'maxfare ~ market_type + EntityEffects  + TimeEffects',
    data=df).fit(cov_type='clustered', cluster_entity=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3688754860.py in <cell line: 0>()
#       2 import statsmodels.api as sm
#       3
# ----> 4 df = df.set_index(['airline_route_grp','year'])
#       5 # regression 1 ： mean fare
#       6 mod_mean2 = PanelOLS.from_formula(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['airline_route_grp', 'year'] are in the columns"

# %%
print(mod_mean2.summary)
print(mod_min2.summary)
print(mod_gini2.summary)
print(mod_max2.summary)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:               meanfare   R-squared:                        0.0161
# Estimator:                   PanelOLS   R-squared (Between):              0.0011
# No. Observations:              222252   R-squared (Within):               0.0172
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.0278
# Time:                        19:57:36   Log-likelihood                -1.074e+06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3443.8
# Entities:                       11544   P-value                           0.0000
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):          2.191e+05
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# market_type[competitive market]     158.80     0.3728     426.00     0.0000      158.07      159.53
# market_type[hob-space]              174.08     0.3719     468.13     0.0000      173.36      174.81
# ===================================================================================================
#
# F-test for Poolability: 89.176
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                minfare   R-squared:                        0.0022
# Estimator:                   PanelOLS   R-squared (Between):             -0.1060
# No. Observations:              222252   R-squared (Within):               0.0021
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.0138
# Time:                        19:57:39   Log-likelihood                 -9.68e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      468.29
# Entities:                       11544   P-value                           0.0000
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):          6.496e+04
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# market_type[competitive market]     38.417     0.1649     233.03     0.0000      38.094      38.740
# market_type[hob-space]              41.918     0.1645     254.88     0.0000      41.596      42.241
# ===================================================================================================
#
# F-test for Poolability: 21.499
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   gini   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.1273
# No. Observations:              222252   R-squared (Within):               0.0006
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.0012
# Time:                        19:57:43   Log-likelihood                 3.784e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      54.142
# Entities:                       11544   P-value                           0.0000
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):          2.084e+05
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# market_type[competitive market]     0.2279     0.0005     449.97     0.0000      0.2270      0.2289
# market_type[hob-space]              0.2307     0.0005     456.55     0.0000      0.2297      0.2317
# ===================================================================================================
#
# F-test for Poolability: 47.857
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                maxfare   R-squared:                     2.661e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0913
# No. Observations:              222252   R-squared (Within):            -4.95e-05
# Date:                Mon, Nov 17 2025   R-squared (Overall):              0.0007
# Time:                        19:57:46   Log-likelihood                -1.721e+06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      5.6068
# Entities:                       11544   P-value                           0.0179
# Avg Obs:                       19.253   Distribution:                F(1,210694)
# Min Obs:                       1.0000
# Max Obs:                       55.000   F-statistic (robust):            3.2e+04
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                F(1,210694)
# Avg Obs:                    1.588e+04
# Min Obs:                    1.187e+04
# Max Obs:                    1.752e+04
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# market_type[competitive market]     564.92     3.1021     182.11     0.0000      558.84      571.00
# market_type[hob-space]              553.61     3.0947     178.89     0.0000      547.54      559.67
# ===================================================================================================
#
# F-test for Poolability: 7.1096
# P-value: 0.0000
# Distribution: F(11556,210694)
#
# Included effects: Entity, Time
